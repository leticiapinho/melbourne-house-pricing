# %% [markdown]
# ## Lesson on predictive models and how to use the data to feed them
#
# The objective of this work is to understand the dataset and generate a predictive model for the sale price of homes in the City of Melbourne (Canada).
# Steps were taken:
#
# * Exploratory data analysis
# * Data cleaning
# * Data visualization
# * Modeling
#
# This analysis is part of the work carried out in the Exemplaria course -AIMF Exemplary.

# %%
# Importing the libraries

import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns; sns.set(style="ticks", color_codes=True)

# %matplotlib inline

# %%
from main import Houses
dataframe = Houses()
dataframe.getHead().head()

# %% [markdown]
# ###  Data Cleaning

# %%
# Displaying the first elements
df.head(3)
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford    68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford     85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/09/2016       2.5    3067.0       2.0       1.0  1.0     126.0
# 1  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
#
#    BuildingArea  YearBuilt         CouncilArea  Lattitude  Longtitude  \
# 0           NaN        NaN  Yarra City Council   -37.8014    144.9958
# 1           NaN        NaN  Yarra City Council   -37.7996    144.9984
# 2          79.0     1900.0  Yarra City Council   -37.8079    144.9934
#
#               Regionname  Propertycount
# 0  Northern Metropolitan         4019.0
# 1  Northern Metropolitan         4019.0
# 2  Northern Metropolitan         4019.0

# %%
# Displaying the last elements
df.tail(3)
# Out:
#            Suburb           Address  Rooms Type      Price Method  \
# 34854  Yarraville    147A Severn St      2    t   705000.0      S
# 34855  Yarraville  12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 34854            Jas  24/02/2018       6.3    3013.0       2.0       1.0  2.0
# 34855  hockingstuart  24/02/2018       6.3    3013.0       NaN       NaN  NaN
# 34856             RW  24/02/2018       6.3    3013.0       2.0       1.0  0.0
#
#        Landsize  BuildingArea  YearBuilt               CouncilArea  Lattitude  \
# 34854     220.0         120.0     2000.0  Maribyrnong City Council  -37.82286
# 34855       NaN           NaN        NaN  Maribyrnong City Council        NaN
# 34856     250.0         103.0     1930.0  Maribyrnong City Council  -37.81810
#
#        Longtitude            Regionname  Propertycount
# 34854   144.87856  Western Metropolitan         6543.0
# 34855         NaN  Western Metropolitan         6543.0
# 34856   144.89351  Western Metropolitan         6543.0

# %%
df.shape
# Out:
# (34857, 21)

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
# Suburb           34857 non-null object
# Address          34857 non-null object
# Rooms            34857 non-null int64
# Type             34857 non-null object
# Price            27247 non-null float64
# Method           34857 non-null object
# SellerG          34857 non-null object
# Date             34857 non-null object
# Distance         34856 non-null float64
# Postcode         34856 non-null float64
# Bedroom2         26640 non-null float64
# Bathroom         26631 non-null float64
# Car              26129 non-null float64
# Landsize         23047 non-null float64
# BuildingArea     13742 non-null float64
# YearBuilt        15551 non-null float64
# CouncilArea      34854 non-null object
# Lattitude        26881 non-null float64
# Longtitude       26881 non-null float64
# Regionname       34854 non-null object
# Propertycount    34854 non-null float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 5.6+ MB

# %%
from datetime import date

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
#df.info()

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# std        0.724212      1.010771    3398.841946     401.26706     37.328178
# min        0.000000      0.000000       0.000000       0.00000   1196.000000
# 25%        1.000000      1.000000     224.000000     102.00000   1940.000000
# 50%        2.000000      2.000000     521.000000     136.00000   1970.000000
# 75%        2.000000      2.000000     670.000000     188.00000   2000.000000
# max       12.000000     26.000000  433014.000000   44515.00000   2106.000000
#
#           Lattitude    Longtitude  Propertycount
# count  26881.000000  26881.000000   34854.000000
# mean     -37.810634    145.001851    7572.888306
# std        0.090279      0.120169    4428.090313
# min      -38.190430    144.423790      83.000000
# 25%      -37.862950    144.933500    4385.000000
# 50%      -37.807600    145.007800    6763.000000
# 75%      -37.754100    145.071900   10412.000000
# max      -37.390200    145.526350   21650.000000

# %%
df['Age'] = 2020 - df['YearBuilt']

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0 2016-03-09       2.5    3067.0       2.0       1.0  1.0     126.0
# 1 2016-03-12       2.5    3067.0       2.0       1.0  1.0     202.0
# 2 2016-04-02       2.5    3067.0       2.0       1.0  0.0     156.0
# 3 2016-04-02       2.5    3067.0       3.0       2.0  1.0       0.0
# 4 2017-04-03       2.5    3067.0       3.0       2.0  0.0     134.0
#
#    BuildingArea  YearBuilt         CouncilArea  Lattitude  Longtitude  \
# 0           NaN        NaN  Yarra City Council   -37.8014    144.9958
# 1           NaN        NaN  Yarra City Council   -37.7996    144.9984
# 2          79.0     1900.0  Yarra City Council   -37.8079    144.9934
# 3           NaN        NaN  Yarra City Council   -37.8114    145.0116
# 4         150.0     1900.0  Yarra City Council   -37.8093    144.9944
#
#               Regionname  Propertycount    Age
# 0  Northern Metropolitan         4019.0    NaN
# 1  Northern Metropolitan         4019.0    NaN
# 2  Northern Metropolitan         4019.0  120.0
# 3  Northern Metropolitan         4019.0    NaN
# 4  Northern Metropolitan         4019.0  120.0

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# std        0.724212      1.010771    3398.841946     401.26706     37.328178
# min        0.000000      0.000000       0.000000       0.00000   1196.000000
# 25%        1.000000      1.000000     224.000000     102.00000   1940.000000
# 50%        2.000000      2.000000     521.000000     136.00000   1970.000000
# 75%        2.000000      2.000000     670.000000     188.00000   2000.000000
# max       12.000000     26.000000  433014.000000   44515.00000   2106.000000
#
#           Lattitude    Longtitude  Propertycount           Age
# count  26881.000000  26881.000000   34854.000000  15551.000000
# mean     -37.810634    145.001851    7572.888306     54.710115
# std        0.090279      0.120169    4428.090313     37.328178
# min      -38.190430    144.423790      83.000000    -86.000000
# 25%      -37.862950    144.933500    4385.000000     20.000000
# 50%      -37.807600    145.007800    6763.000000     50.000000
# 75%      -37.754100    145.071900   10412.000000     80.000000
# max      -37.390200    145.526350   21650.000000    824.000000

# %% [markdown]
# Melbourne was founded on August 30, 1835, 185 years ago. It is strange to appear houses older than that date in dataset.
# For illustrating this, in fast google research we found the oldest building in Melbourne is Cooks' Cottage (1755), the two-storey brick cottage is a copy from other building in England.
# The oldest building originally built in Melbourne is St James' Old Cathedral (1839).
# So, its reasonable eliminate registers with age greater than 185 years.

# %%
# Remove outliers
df = df[(df['Age']<185)]

# %%
df.head()
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 2  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 4  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
# 6  Abbotsford      55a Park St      4    h  1600000.0     VB  Nelson
# 7  Abbotsford     16 Maugie St      4    h        NaN     SN  Nelson
# 8  Abbotsford     53 Turner St      2    h        NaN      S  Biggin
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 2 2016-04-02       2.5    3067.0       2.0       1.0  0.0     156.0
# 4 2017-04-03       2.5    3067.0       3.0       2.0  0.0     134.0
# 6 2016-04-06       2.5    3067.0       3.0       1.0  2.0     120.0
# 7 2016-06-08       2.5    3067.0       3.0       2.0  2.0     400.0
# 8 2016-06-08       2.5    3067.0       4.0       1.0  2.0     201.0
#
#    BuildingArea  YearBuilt         CouncilArea  Lattitude  Longtitude  \
# 2          79.0     1900.0  Yarra City Council   -37.8079    144.9934
# 4         150.0     1900.0  Yarra City Council   -37.8093    144.9944
# 6         142.0     2014.0  Yarra City Council   -37.8072    144.9941
# 7         220.0     2006.0  Yarra City Council   -37.7965    144.9965
# 8           NaN     1900.0  Yarra City Council   -37.7995    144.9974
#
#               Regionname  Propertycount    Age
# 2  Northern Metropolitan         4019.0  120.0
# 4  Northern Metropolitan         4019.0  120.0
# 6  Northern Metropolitan         4019.0    6.0
# 7  Northern Metropolitan         4019.0   14.0
# 8  Northern Metropolitan         4019.0  120.0

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  15547.000000  1.208100e+04  15547.000000  15547.000000  15547.000000
# mean       3.108574  1.077239e+06     11.154049   3117.080659      3.090435
# std        0.986488  6.713992e+05      6.945201    115.284192      1.008737
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.320000e+05      6.300000   3047.000000      2.000000
# 50%        3.000000  8.850000e+05     10.100000   3101.000000      3.000000
# 75%        4.000000  1.320000e+06     14.000000   3155.000000      4.000000
# max       12.000000  9.000000e+06     48.100000   3978.000000     30.000000
#
#            Bathroom           Car      Landsize  BuildingArea     YearBuilt  \
# count  15546.000000  15295.000000  13712.000000  13234.000000  15547.000000
# mean       1.670526      1.704086    531.413652    153.921488   1965.368045
# std        0.735028      1.000872   1053.269465     88.974518     36.761183
# min        0.000000      0.000000      0.000000      0.000000   1850.000000
# 25%        1.000000      1.000000    204.000000    102.000000   1940.000000
# 50%        2.000000      2.000000    470.000000    135.000000   1970.000000
# 75%        2.000000      2.000000    658.000000    186.000000   2000.000000
# max       12.000000     26.000000  42800.000000   3112.000000   2106.000000
#
#           Lattitude    Longtitude  Propertycount           Age
# count  15538.000000  15538.000000   15547.000000  15547.000000
# mean     -37.809463    144.998997    7520.486203     54.631955
# std        0.090200      0.119818    4302.332966     36.761183
# min      -38.190430    144.423790     129.000000    -86.000000
# 25%      -37.861300    144.930692    4442.000000     20.000000
# 50%      -37.807700    145.004800    6763.000000     50.000000
# 75%      -37.754900    145.068723   10331.000000     80.000000
# max      -37.390200    145.526350   21650.000000    170.000000

# %% [markdown]
# ### Exploratory Data Analysis

# %%
plt.figure(figsize=(16,7))
sns.distplot(df['Age'], kde = False,hist_kws=dict(edgecolor="k"))
# Out:
# C:\Users\letic\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['CouncilArea'].value_counts()
# Out:
# Boroondara City Council           1674
# Darebin City Council              1190
# Moreland City Council              990
# Melbourne City Council             890
# Glen Eira City Council             848
# Moonee Valley City Council         810
# Banyule City Council               771
# Maribyrnong City Council           742
# Bayside City Council               719
# Brimbank City Council              659
# Stonnington City Council           623
# Port Phillip City Council          620
# Hume City Council                  618
# Monash City Council                578
# Yarra City Council                 566
# Manningham City Council            433
# Hobsons Bay City Council           429
# Whittlesea City Council            399
# Kingston City Council              350
# Wyndham City Council               310
# Whitehorse City Council            252
# Maroondah City Council             229
# Melton City Council                177
# Knox City Council                  171
# Frankston City Council             144
# Greater Dandenong City Council     122
# Casey City Council                  94
# Nillumbik Shire Council             48
# Yarra Ranges Shire Council          40
# Cardinia Shire Council              22
# Macedon Ranges Shire Council        18
# Mitchell Shire Council               9
# Moorabool Shire Council              2
# Name: CouncilArea, dtype: int64

# %%
df['Regionname'].value_counts()
# Out:
# Southern Metropolitan         5253
# Northern Metropolitan         4296
# Western Metropolitan          3147
# Eastern Metropolitan          1834
# South-Eastern Metropolitan     730
# Northern Victoria              110
# Eastern Victoria               103
# Western Victoria                74
# Name: Regionname, dtype: int64

# %%
df['Regionname'].value_counts().plot.bar(title='Freq dist of Regions')

# %%
df['CouncilArea'].value_counts().plot.bar(title='Freq dist of Regions')

# %%
# use the pairplot to plot bivariate distributions and uderstand the relationship between two variables

sns.pairplot(df, vars=['Rooms','Price', 'Bedroom2', 'Bathroom', 'Car',
        'Age', 'Propertycount'], hue='Regionname', palette='husl' )
# Out:
# C:\Users\letic\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\letic\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
# Correlation between some variables with one another (All dataset)

plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),cmap = 'coolwarm',linewidth = 1,annot= True, annot_kws={"size": 9})
plt.title('Variable Correlation')
# Out:
# Text(0.5, 1.0, 'Variable Correlation')

# %% [markdown]
# The dataset has many Nan values, which can cause problems in the model. I will do two approaches. The first eliminating lines (dropna) with missing values and the second with the imputation of value. The proposal is to see the impact on the data and there is a difference in the results of the model.

# %%
# First: Count of missing values
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            3466
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            1
# Car               252
# Landsize         1835
# BuildingArea     2313
# YearBuilt           0
# CouncilArea         0
# Lattitude           9
# Longtitude          9
# Regionname          0
# Propertycount       0
# Age                 0
# dtype: int64

# %%
# Percentage of Nan values
df.isnull().sum()/len(df)*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price            22.293690
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.000000
# Postcode          0.000000
# Bedroom2          0.000000
# Bathroom          0.006432
# Car               1.620891
# Landsize         11.802920
# BuildingArea     14.877468
# YearBuilt         0.000000
# CouncilArea       0.000000
# Lattitude         0.057889
# Longtitude        0.057889
# Regionname        0.000000
# Propertycount     0.000000
# Age               0.000000
# dtype: float64

# %%
# Using dropna() function   
df_dropp = df.dropna()

# %%
df_dropp.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# Age              0
# dtype: int64

# %%
df_dropp.shape
# Out:
# (8885, 22)

# %% [markdown]
# It's very different! With Nan values, the dataset's size is 34857 rows and without nan values, only 8887 rows. There are 25,970 fewer cases, a big loss.

# %%
# Distplot to plot and analyze the univariate distribution of the numerical columns

col_names = ['Rooms','Price', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea','YearBuilt', 'Age']

fig, ax = plt.subplots(len(col_names), figsize=(16,12))

for i, col_val in enumerate(col_names):

    sns.distplot(df_dropp[col_val], hist=True, ax=ax[i])
    ax[i].set_title('Freq dist '+col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
    ax[i].set_ylabel('Count', fontsize=8)

plt.show()

# %%
# Use the pairplot to plot bivariate distributions and uderstand the relationship between two variables

sns.pairplot(df_dropp, vars=['Rooms','Price', 'Bedroom2', 'Bathroom', 'Car',
        'Age', 'Propertycount'], hue='Regionname', palette='husl' )

# %%
# Correlation between some variables with one another (without Nan values)

plt.figure(figsize=(15,10))
sns.heatmap(df_dropp.corr(),cmap = 'coolwarm',linewidth = 1,annot= True, annot_kws={"size": 9})
plt.title('Variable Correlation')
# Out:
# Text(0.5, 1.0, 'Variable Correlation')

# %% [markdown]
# ### Random Forest Regression model
#
# Now I'll do some tests with a random forest model.

# %%
# Splitting the dataset into training set and test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-fbd5fe040952> in <module>
#       2
#       3 from sklearn.model_selection import train_test_split
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)
#
# NameError: name 'X' is not defined

# %% [markdown]
# #### Imputation

# %%
# next steps

#df_fitered = df.fillna(df.mean(), inplace=True)
